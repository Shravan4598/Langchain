# %%
from langchain_community.tools import tool

# %%
! pip install langchain-community
# Out:
# Requirement already satisfied: langchain-community in c:\users\shrav\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-community) (1.4.9)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-community) (0.10.1)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-community) (2.14.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\shrav\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\shrav\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\shrav\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\shrav\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\shrav\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\shrav\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (4.14.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\shrav\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.17.0)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\shrav\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.2.0)
# Requirement already satisfied: distro>=1.7.0 in c:\users\shrav\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\shrav\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\shrav\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\shrav\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\shrav\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in c:\users\shrav\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (16.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\shrav\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\shrav\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\shrav\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\shrav\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\shrav\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shrav\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.10)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\shrav\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\shrav\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2025.8.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\shrav\anaconda3\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.3)
# Requirement already satisfied: httpcore==1.* in c:\users\shrav\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\shrav\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\shrav\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\shrav\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\shrav\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.20.1)

# %%
# Python function
def multiply(a,b):
    """Multiply two numbers"""
    return a*b

# %%
#type hinting
def multiply(a:int,b:int)->int:
    """Multiply two numbers"""
    return a*b

# %%
# tool decorator
@tool
def multiply(a:int,b:int)->int:
    """Multiply two numbers"""
    return a*b

# %%
result=multiply.invoke({"a":5,"b":3})
print(result)
# Out:
# 15

# %%
print("Description:",multiply.description)
print("Name:",multiply.name)
print("Arguments:",multiply.args)
# Out:
# Description: Multiply two numbers
# Name: multiply
# Arguments: {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}

# %%
print(multiply.args_schema.model_json_schema())
# Out:
# {'description': 'Multiply two numbers', 'properties': {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}, 'required': ['a', 'b'], 'title': 'multiply', 'type': 'object'}
